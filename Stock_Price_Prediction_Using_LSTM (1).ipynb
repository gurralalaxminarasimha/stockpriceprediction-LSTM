# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/ADANIENT.NS.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-09-05  3374.100098  3431.800049  3313.000000  3346.550049
# 1  2022-09-06  3370.000000  3447.600098  3355.000000  3435.800049
# 2  2022-09-07  3435.800049  3487.949951  3406.100098  3473.750000
# 3  2022-09-08  3499.000000  3501.500000  3450.000000  3462.800049
# 4  2022-09-09  3479.000000  3507.949951  3415.149902  3451.199951
# 5  2022-09-12  3465.000000  3495.500000  3457.899902  3463.800049
# 6  2022-09-13  3478.000000  3568.899902  3421.300049  3555.800049
# 7  2022-09-14  3518.000000  3608.000000  3511.000000  3572.100098
# 8  2022-09-15  3590.000000  3767.949951  3575.000000  3748.699951
# 9  2022-09-16  3755.000000  3866.949951  3614.600098  3702.199951
#
#      Adj Close   Volume
# 0  3343.205811  3686950
# 1  3432.366455  2580772
# 2  3470.278564  2188110
# 3  3459.339600  1560414
# 4  3447.751221  1614634
# 5  3460.338623  1647756
# 6  3552.246582  3479669
# 7  3568.530518  2740337
# 8  3744.953613  4716688
# 9  3698.500244  5687429

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (249, 7)

# %%
# statistical description of data
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   249.000000   249.000000   249.000000   249.000000   249.000000
# mean   2772.205017  2822.699187  2703.427716  2760.094981  2757.748979
# std     826.752842   821.624501   831.583658   826.763120   825.795662
# min    1145.000000  1313.800049  1017.450012  1193.500000  1192.307373
# 25%    1935.000000  1990.000000  1881.000000  1924.949951  1923.026245
# 50%    2499.199951  2549.000000  2455.649902  2492.199951  2490.858398
# 75%    3583.500000  3629.550049  3526.000000  3580.699951  3577.121582
# max    4175.000000  4190.000000  4066.399902  4165.299805  4161.137207
#
#              Volume
# count  2.490000e+02
# mean   5.450796e+06
# std    6.258598e+06
# min    0.000000e+00
# 25%    1.863848e+06
# 50%    3.294056e+06
# 75%    6.127920e+06
# max    4.388558e+07

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       249 non-null    object
#  1   Open       249 non-null    float64
#  2   High       249 non-null    float64
#  3   Low        249 non-null    float64
#  4   Close      249 non-null    float64
#  5   Adj Close  249 non-null    float64
#  6   Volume     249 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df = df[['Date','Open','Close']] # Extracting required columns
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('Date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#                    Open        Close
# Date
# 2022-09-05  3374.100098  3346.550049
# 2022-09-06  3370.000000  3435.800049
# 2022-09-07  3435.800049  3473.750000
# 2022-09-08  3499.000000  3462.800049
# 2022-09-09  3479.000000  3451.199951
# 2022-09-12  3465.000000  3463.800049
# 2022-09-13  3478.000000  3555.800049
# 2022-09-14  3518.000000  3572.100098
# 2022-09-15  3590.000000  3748.699951
# 2022-09-16  3755.000000  3702.199951

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['Close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2022-09-05  0.735677  0.724494
# 2022-09-06  0.734323  0.754526
# 2022-09-07  0.756040  0.767296
# 2022-09-08  0.776898  0.763611
# 2022-09-09  0.770297  0.759708
# 2022-09-12  0.765677  0.763948
# 2022-09-13  0.769967  0.794906
# 2022-09-14  0.783168  0.800390
# 2022-09-15  0.806931  0.859816
# 2022-09-16  0.861386  0.844169

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 187

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((187, 2), (62, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((137, 50, 2), (137, 2), (12, 50, 2), (12, 2))

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 6s 389ms/step - loss: 0.2773 - mean_absolute_error: 0.4251 - val_loss: 0.0289 - val_mean_absolute_error: 0.1666
# Epoch 2/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0488 - mean_absolute_error: 0.1699 - val_loss: 0.0402 - val_mean_absolute_error: 0.1958
# Epoch 3/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0522 - mean_absolute_error: 0.1654 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277
# Epoch 4/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0304 - mean_absolute_error: 0.1355 - val_loss: 0.0090 - val_mean_absolute_error: 0.0891
# Epoch 5/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0337 - mean_absolute_error: 0.1463 - val_loss: 0.0036 - val_mean_absolute_error: 0.0508
# Epoch 6/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0232 - mean_absolute_error: 0.1152 - val_loss: 0.0031 - val_mean_absolute_error: 0.0494
# Epoch 7/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0239 - mean_absolute_error: 0.1014 - val_loss: 0.0052 - val_mean_absolute_error: 0.0641
# Epoch 8/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0215 - mean_absolute_error: 0.0971 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 9/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0176 - mean_absolute_error: 0.0929 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 10/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0172 - mean_absolute_error: 0.0934 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 11/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0145 - mean_absolute_error: 0.0771 - val_loss: 0.0011 - val_mean_absolute_error: 0.0269
# Epoch 12/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0138 - mean_absolute_error: 0.0747 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 13/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0132 - mean_absolute_error: 0.0756 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 14/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0122 - mean_absolute_error: 0.0684 - val_loss: 0.0014 - val_mean_absolute_error: 0.0276
# Epoch 15/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0117 - mean_absolute_error: 0.0729 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 16/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0109 - mean_absolute_error: 0.0689 - val_loss: 0.0010 - val_mean_absolute_error: 0.0262
# Epoch 17/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0115 - mean_absolute_error: 0.0623 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 18/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0106 - mean_absolute_error: 0.0711 - val_loss: 0.0021 - val_mean_absolute_error: 0.0351
# Epoch 19/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0098 - mean_absolute_error: 0.0659 - val_loss: 0.0014 - val_mean_absolute_error: 0.0333
# Epoch 20/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0095 - mean_absolute_error: 0.0612 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 21/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0086 - mean_absolute_error: 0.0589 - val_loss: 0.0011 - val_mean_absolute_error: 0.0270
# Epoch 22/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0091 - mean_absolute_error: 0.0620 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 23/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0088 - mean_absolute_error: 0.0632 - val_loss: 0.0010 - val_mean_absolute_error: 0.0258
# Epoch 24/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0086 - mean_absolute_error: 0.0607 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 25/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0086 - mean_absolute_error: 0.0616 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 26/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0101 - mean_absolute_error: 0.0720 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 27/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0094 - mean_absolute_error: 0.0675 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 28/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0088 - mean_absolute_error: 0.0640 - val_loss: 0.0015 - val_mean_absolute_error: 0.0289
# Epoch 29/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0084 - mean_absolute_error: 0.0599 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 30/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0080 - mean_absolute_error: 0.0602 - val_loss: 0.0013 - val_mean_absolute_error: 0.0259
# Epoch 31/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0081 - mean_absolute_error: 0.0595 - val_loss: 0.0010 - val_mean_absolute_error: 0.0257
# Epoch 32/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0083 - mean_absolute_error: 0.0614 - val_loss: 0.0016 - val_mean_absolute_error: 0.0291
# Epoch 33/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0082 - mean_absolute_error: 0.0599 - val_loss: 0.0012 - val_mean_absolute_error: 0.0251
# Epoch 34/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0083 - mean_absolute_error: 0.0590 - val_loss: 0.0015 - val_mean_absolute_error: 0.0282
# Epoch 35/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0085 - mean_absolute_error: 0.0612 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269
# Epoch 36/100
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0083 - mean_absolute_error: 0.0594 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 37/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0082 - mean_absolute_error: 0.0586 - val_loss: 0.0016 - val_mean_absolute_error: 0.0290
# Epoch 38/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0074 - mean_absolute_error: 0.0587 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 39/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0078 - mean_absolute_error: 0.0577 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 40/100
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0078 - mean_absolute_error: 0.0568 - val_loss: 0.0017 - val_mean_absolute_error: 0.0305
# Epoch 41/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0074 - mean_absolute_error: 0.0597 - val_loss: 0.0015 - val_mean_absolute_error: 0.0286
# Epoch 42/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0077 - mean_absolute_error: 0.0586 - val_loss: 0.0015 - val_mean_absolute_error: 0.0282
# Epoch 43/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0070 - mean_absolute_error: 0.0560 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 44/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0075 - mean_absolute_error: 0.0583 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# Epoch 45/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0085 - mean_absolute_error: 0.0662 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 46/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0117 - mean_absolute_error: 0.0747 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
# Epoch 47/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0085 - mean_absolute_error: 0.0648 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 48/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0083 - mean_absolute_error: 0.0577 - val_loss: 0.0017 - val_mean_absolute_error: 0.0300
# Epoch 49/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0080 - mean_absolute_error: 0.0626 - val_loss: 0.0019 - val_mean_absolute_error: 0.0331
# Epoch 50/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0073 - mean_absolute_error: 0.0549 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 51/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0070 - mean_absolute_error: 0.0537 - val_loss: 0.0029 - val_mean_absolute_error: 0.0442
# Epoch 52/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0074 - mean_absolute_error: 0.0608 - val_loss: 0.0016 - val_mean_absolute_error: 0.0299
# Epoch 53/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0065 - mean_absolute_error: 0.0537 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 54/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0072 - mean_absolute_error: 0.0574 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# Epoch 55/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0068 - mean_absolute_error: 0.0566 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268
# Epoch 56/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0072 - mean_absolute_error: 0.0554 - val_loss: 0.0019 - val_mean_absolute_error: 0.0331
# Epoch 57/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0071 - mean_absolute_error: 0.0585 - val_loss: 0.0018 - val_mean_absolute_error: 0.0322
# Epoch 58/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0070 - mean_absolute_error: 0.0571 - val_loss: 0.0020 - val_mean_absolute_error: 0.0341
# Epoch 59/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0068 - mean_absolute_error: 0.0570 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 60/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0068 - mean_absolute_error: 0.0571 - val_loss: 0.0017 - val_mean_absolute_error: 0.0300
# Epoch 61/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0067 - mean_absolute_error: 0.0569 - val_loss: 0.0018 - val_mean_absolute_error: 0.0320
# Epoch 62/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0064 - mean_absolute_error: 0.0533 - val_loss: 0.0019 - val_mean_absolute_error: 0.0331
# Epoch 63/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0066 - mean_absolute_error: 0.0563 - val_loss: 0.0020 - val_mean_absolute_error: 0.0336
# Epoch 64/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0063 - mean_absolute_error: 0.0544 - val_loss: 0.0027 - val_mean_absolute_error: 0.0421
# Epoch 65/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0071 - mean_absolute_error: 0.0604 - val_loss: 0.0018 - val_mean_absolute_error: 0.0318
# Epoch 66/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0069 - mean_absolute_error: 0.0575 - val_loss: 0.0034 - val_mean_absolute_error: 0.0492
# Epoch 67/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0067 - mean_absolute_error: 0.0602 - val_loss: 0.0012 - val_mean_absolute_error: 0.0248
# Epoch 68/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0073 - mean_absolute_error: 0.0607 - val_loss: 0.0028 - val_mean_absolute_error: 0.0432
# Epoch 69/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0061 - mean_absolute_error: 0.0536 - val_loss: 0.0018 - val_mean_absolute_error: 0.0314
# Epoch 70/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0064 - mean_absolute_error: 0.0537 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# Epoch 71/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0062 - mean_absolute_error: 0.0547 - val_loss: 0.0036 - val_mean_absolute_error: 0.0511
# Epoch 72/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0064 - mean_absolute_error: 0.0541 - val_loss: 0.0029 - val_mean_absolute_error: 0.0445
# Epoch 73/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0060 - mean_absolute_error: 0.0530 - val_loss: 0.0035 - val_mean_absolute_error: 0.0506
# Epoch 74/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0062 - mean_absolute_error: 0.0537 - val_loss: 0.0027 - val_mean_absolute_error: 0.0423
# Epoch 75/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0057 - mean_absolute_error: 0.0513 - val_loss: 0.0030 - val_mean_absolute_error: 0.0457
# Epoch 76/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 77/100
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0058 - mean_absolute_error: 0.0524 - val_loss: 0.0028 - val_mean_absolute_error: 0.0437
# Epoch 78/100
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0058 - mean_absolute_error: 0.0524 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 79/100
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0064 - mean_absolute_error: 0.0581 - val_loss: 0.0025 - val_mean_absolute_error: 0.0400
# Epoch 80/100
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0055 - mean_absolute_error: 0.0500 - val_loss: 0.0034 - val_mean_absolute_error: 0.0496
# Epoch 81/100
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0062 - mean_absolute_error: 0.0548 - val_loss: 0.0027 - val_mean_absolute_error: 0.0428
# Epoch 82/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0057 - mean_absolute_error: 0.0490 - val_loss: 0.0028 - val_mean_absolute_error: 0.0436
# Epoch 83/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0056 - mean_absolute_error: 0.0477 - val_loss: 0.0034 - val_mean_absolute_error: 0.0492
# Epoch 84/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0060 - mean_absolute_error: 0.0528 - val_loss: 0.0031 - val_mean_absolute_error: 0.0469
# Epoch 85/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0058 - mean_absolute_error: 0.0523 - val_loss: 0.0035 - val_mean_absolute_error: 0.0506
# Epoch 86/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0057 - mean_absolute_error: 0.0508 - val_loss: 0.0028 - val_mean_absolute_error: 0.0432
# Epoch 87/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0054 - mean_absolute_error: 0.0489 - val_loss: 0.0033 - val_mean_absolute_error: 0.0491
# Epoch 88/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0058 - mean_absolute_error: 0.0511 - val_loss: 0.0043 - val_mean_absolute_error: 0.0576
# Epoch 89/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0060 - mean_absolute_error: 0.0568 - val_loss: 0.0024 - val_mean_absolute_error: 0.0388
# Epoch 90/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0061 - mean_absolute_error: 0.0532 - val_loss: 0.0061 - val_mean_absolute_error: 0.0715
# Epoch 91/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0067 - mean_absolute_error: 0.0609 - val_loss: 0.0013 - val_mean_absolute_error: 0.0251
# Epoch 92/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0066 - mean_absolute_error: 0.0563 - val_loss: 0.0052 - val_mean_absolute_error: 0.0656
# Epoch 93/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0063 - mean_absolute_error: 0.0581 - val_loss: 0.0012 - val_mean_absolute_error: 0.0246
# Epoch 94/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0061 - mean_absolute_error: 0.0544 - val_loss: 0.0049 - val_mean_absolute_error: 0.0628
# Epoch 95/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0059 - mean_absolute_error: 0.0554 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 96/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0070 - mean_absolute_error: 0.0579 - val_loss: 0.0054 - val_mean_absolute_error: 0.0664
# Epoch 97/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0061 - mean_absolute_error: 0.0574 - val_loss: 0.0011 - val_mean_absolute_error: 0.0239
# Epoch 98/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0067 - mean_absolute_error: 0.0566 - val_loss: 0.0043 - val_mean_absolute_error: 0.0575
# Epoch 99/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0066 - mean_absolute_error: 0.0610 - val_loss: 0.0021 - val_mean_absolute_error: 0.0356
# Epoch 100/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0069 - mean_absolute_error: 0.0551 - val_loss: 0.0020 - val_mean_absolute_error: 0.0341

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 1/1 [==============================] - 1s 784ms/step
# array([[0.41924053, 0.40189072],
#        [0.4184423 , 0.40116242],
#        [0.4222191 , 0.40486965],
#        [0.43046308, 0.41293097],
#        [0.43760204, 0.419833  ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[2415.2988, 2387.8389],
#        [2412.8801, 2385.6746],
#        [2424.324 , 2396.6917],
#        [2449.3032, 2420.6482],
#        [2470.934 , 2441.1597]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-12:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-12:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['Open','Close']] = MMS.inverse_transform(df_merge[['Open','Close']])
df_merge.head()
# Out:
#                    Open        Close  open_predicted  close_predicted
# Date
# 2023-08-18  2477.500000  2577.399902     2415.298828      2387.838867
# 2023-08-21  2588.000000  2639.750000     2412.880127      2385.674561
# 2023-08-22  2668.850098  2698.050049     2424.323975      2396.691650
# 2023-08-23  2720.000000  2530.300049     2449.303223      2420.648193
# 2023-08-24  2580.000000  2539.550049     2470.934082      2441.159668

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['Open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['Close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2023-09-05':'2023-09-20']
# Out:
#             Open  Close  open_predicted  close_predicted
# 2023-09-05   NaN    NaN             NaN              NaN
# 2023-09-06   NaN    NaN             NaN              NaN
# 2023-09-07   NaN    NaN             NaN              NaN
# 2023-09-08   NaN    NaN             NaN              NaN
# 2023-09-09   NaN    NaN             NaN              NaN
# 2023-09-10   NaN    NaN             NaN              NaN
# 2023-09-11   NaN    NaN             NaN              NaN
# 2023-09-12   NaN    NaN             NaN              NaN
# 2023-09-13   NaN    NaN             NaN              NaN
# 2023-09-14   NaN    NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['Open','Close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['Open','Close']] = MMS.inverse_transform(upcoming_prediction[['Open','Close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2023-08-07':,'Open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2023-08-07':,'Open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=25)
ax.set_title('Upcoming Open price prediction',size=25)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2023-08-07':,'Close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2023-08-07':,'Close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
